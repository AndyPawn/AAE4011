# %% [markdown]
# # Jupyter Notebook 笔记教程
#
# # 1. 使用 Markdown 单元格做笔记
# # Markdown 是一种轻量级标记语言，可以用来格式化文本
#
# # 这是一个标题
# # ## 这是一个二级标题
# # ### 这是一个三级标题
#
# # 这是一个段落，可以用来写笔记。
#
# # 这是一个列表：
# # - 项目1
# # - 项目2
# # - 项目3
#
# # 这是一个代码块的示例：
# # ```python
# # print("Hello, World!")
# # ```
#
# # 2. 使用代码单元格做笔记
# # 你可以在代码单元格中运行代码，并查看结果
#
# # 示例1: 打印输出
# print("这是一个简单的打印输出示例。")
#
# # 示例2: 计算
# a = 5
# b = 10
# sum_result = a + b
# print(f"{a} + {b} = {sum_result}")
#
# # 3. 使用 LaTeX 做数学公式笔记
# # 你可以在 Markdown 单元格中使用 LaTeX 语法来编写数学公式
#
# # 这是一个行内公式：$E = mc^2$
#
# # 这是一个独立公式：
# # $$
# # \int_{a}^{b} x^2 dx
# # $$
#
# # 4. 使用注释做笔记
# # 你可以在代码单元格中使用注释来解释代码
#
# # 这是一个注释示例
# x = 10  # 这是一个变量赋值
#
# # 5. 使用图像做笔记
# # 你可以在 Markdown 单元格中插入图像
#
# # ![示例图像](https://via.placeholder.com/150)
#
# # 6. 使用表格做笔记
# # 你可以在 Markdown 单元格中创建表格
#
# # | 序号 | 名称 | 描述 |
# # | ---- | ---- | ---- |
# # | 1    | 项目1 | 描述1 |
# # | 2    | 项目2 | 描述2 |
# # | 3    | 项目3 | 描述3 |
#
# # 7. 使用链接做笔记
# # 你可以在 Markdown 单元格中插入链接
#
# # [这是一个链接](https://www.example.com)
#
# # 8. 使用代码高亮做笔记
# # 你可以在 Markdown 单元格中使用代码高亮
#
# # ```python
# # def hello_world():
# #     print("Hello, World!")
# # ```
#
# # 9. 使用内嵌 HTML 做笔记
# # 你可以在 Markdown 单元格中使用 HTML 标签
#
# # <b>这是一个加粗的文本</b>
#
# # 10. 使用内嵌视频做笔记
# # 你可以在 Markdown 单元格中嵌入视频
#
# # <iframe width="560" height="315" src="https://www.youtube.com/embed/dQw4w9WgXcQ" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
#
# # 11. 使用内嵌音频做笔记
# # 你可以在 Markdown 单元格中嵌入音频
#
# # <audio controls>
# #   <source src="https://www.soundhelix.com/examples/mp3/SoundHelix-Song-1.mp3" type="audio/mpeg">
# # </audio>
#
# # 12. 使用内嵌 PDF 做笔记
# # 你可以在 Markdown 单元格中嵌入 PDF
#
# # <iframe src="https://www.example.com/sample.pdf" width="100%" height="500px"></iframe>
#
# # 13. 使用内嵌地图做笔记
# # 你可以在 Markdown 单元格中嵌入地图
#
# # <iframe src="https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d3153.8354345093747!2d144.9537353153166!3d-37.81627974202105!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x6ad642af0f11fd81%3A0xf577d2d2f2f5c5c5!2sFlinders%20Street%20Station!5e0!3m2!1sen!2sau!4v1625060000000!5m2!1sen!2sau" width="600" height="450" style="border:0;" allowfullscreen="" loading="lazy"></iframe>
#
# # 14. 使用内嵌图表做笔记
# # 你可以在代码单元格中使用 Matplotlib 绘制图表
#
# import matplotlib.pyplot as plt
# import numpy as np
#
# x = np.linspace(0, 10, 100)
# y = np.sin(x)
#
# plt.plot(x, y)
# plt.title("正弦波")
# plt.xlabel("x")
# plt.ylabel("sin(x)")
# plt.show()
#
# # 15. 使用内嵌交互式图表做笔记
# # 你可以在代码单元格中使用 Plotly 绘制交互式图表
#
# import plotly.express as px
#
# df = px.data.iris()
# fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species")
# fig.show()
#
# # 16. 使用内嵌表格做笔记
# # 你可以在代码单元格中使用 Pandas 创建表格
#
# import pandas as pd
#
# data = {
#     "Name": ["Alice", "Bob", "Charlie"],
#     "Age": [25, 30, 35],
#     "City": ["New York", "Los Angeles", "Chicago"]
# }
#
# df = pd.DataFrame(data)
# df
#
# # 17. 使用内嵌图像做笔记
# # 你可以在代码单元格中使用 Matplotlib 显示图像
#
# from PIL import Image
# import matplotlib.pyplot as plt
#
# img = Image.open("example.png")
# plt.imshow(img)
# plt.axis("off")
# plt.show()
#
# # 18. 使用内嵌视频做笔记
# # 你可以在代码单元格中使用 IPython 显示视频
#
# from IPython.display import Video
#
# Video("example.mp4")
#
# # 19. 使用内嵌音频做笔记
# # 你可以在代码单元格中使用 IPython 播放音频
#
# from IPython.display import Audio
#
# Audio("example.mp3")
#
# # 20. 使用内嵌 PDF 做笔记
# # 你可以在代码单元格中使用 IPython 显示 PDF
#
# from IPython.display import IFrame
#
# IFrame("https://www.example.com/sample.pdf", width=600, height=400)
#
# # 21. 使用内嵌地图做笔记
# # 你可以在代码单元格中使用 Folium 创建交互式地图
#
# import folium
#
# m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
# m
#
# # 22. 使用内嵌 3D 图形做笔记
# # 你可以在代码单元格中使用 Plotly 创建 3D 图形
#
# import plotly.graph_objects as go
#
# fig = go.Figure(data=[go.Mesh3d(x=[0, 1, 2, 0], y=[0, 0, 1, 2], z=[0, 2, 0, 1])])
# fig.show()
#
# # 23. 使用内嵌动画做笔记
# # 你可以在代码单元格中使用 Matplotlib 创建动画
#
# import matplotlib.animation as animation
# import numpy as np
#
# fig, ax = plt.subplots()
#
# x = np.arange(0, 2*np.pi, 0.01)
# line, = ax.plot(x, np.sin(x))
#
# def animate(i):
#     line.set_ydata(np.sin(x + i / 50))  # 更新数据
#     return line,
#
# ani = animation.FuncAnimation(fig, animate, interval=20, blit=True, save_count=50)
# plt.show()
#
# # 24. 使用内嵌交互式控件做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式控件
#
# from IPython.display import display
# import ipywidgets as widgets
#
# slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description='Slider:')
# display(slider)
#
# # 25. 使用内嵌交互式表单做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式表单
#
# from IPython.display import display
# import ipywidgets as widgets
#
# text = widgets.Text(value='', placeholder='输入一些文本', description='文本:')
# button = widgets.Button(description='提交')
# output = widgets.Output()
#
# def on_button_click(b):
#     with output:
#         print(f"你输入了: {text.value}")
#
# button.on_click(on_button_click)
#
# display(text, button, output)
#
# # 26. 使用内嵌交互式图表做笔记
# # 你可以在代码单元格中使用 Bokeh 创建交互式图表
#
# from bokeh.plotting import figure, show
# from bokeh.io import output_notebook
#
# output_notebook()
#
# p = figure(title="简单折线图", x_axis_label='x', y_axis_label='y')
# p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="温度", line_width=2)
# show(p)
#
# # 27. 使用内嵌交互式地图做笔记
# # 你可以在代码单元格中使用 Folium 创建交互式地图
#
# import folium
#
# m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
# folium.Marker([37.7749, -122.4194], popup="San Francisco").add_to(m)
# m
#
# # 28. 使用内嵌交互式表格做笔记
# # 你可以在代码单元格中使用 QGrid 创建交互式表格
#
# import qgrid
# import pandas as pd
#
# df = pd.DataFrame({
#     'A': [1, 2, 3],
#     'B': [4, 5, 6],
#     'C': [7, 8, 9]
# })
#
# qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
# qgrid_widget
#
# # 29. 使用内嵌交互式 3D 图形做笔记
# # 你可以在代码单元格中使用 Plotly 创建交互式 3D 图形
#
# import plotly.graph_objects as go
#
# fig = go.Figure(data=[go.Mesh3d(x=[0, 1, 2, 0], y=[0, 0, 1, 2], z=[0, 2, 0, 1])])
# fig.show()
#
# # 30. 使用内嵌交互式动画做笔记
# # 你可以在代码单元格中使用 Matplotlib 创建交互式动画
#
# import matplotlib.animation as animation
# import numpy as np
#
# fig, ax = plt.subplots()
#
# x = np.arange(0, 2*np.pi, 0.01)
# line, = ax.plot(x, np.sin(x))
#
# def animate(i):
#     line.set_ydata(np.sin(x + i / 50))  # 更新数据
#     return line,
#
# ani = animation.FuncAnimation(fig, animate, interval=20, blit=True, save_count=50)
# plt.show()
#
# # 31. 使用内嵌交互式控件做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式控件
#
# from IPython.display import display
# import ipywidgets as widgets
#
# slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description='Slider:')
# display(slider)
#
# # 32. 使用内嵌交互式表单做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式表单
#
# from IPython.display import display
# import ipywidgets as widgets
#
# text = widgets.Text(value='', placeholder='输入一些文本', description='文本:')
# button = widgets.Button(description='提交')
# output = widgets.Output()
#
# def on_button_click(b):
#     with output:
#         print(f"你输入了: {text.value}")
#
# button.on_click(on_button_click)
#
# display(text, button, output)
#
# # 33. 使用内嵌交互式图表做笔记
# # 你可以在代码单元格中使用 Bokeh 创建交互式图表
#
# from bokeh.plotting import figure, show
# from bokeh.io import output_notebook
#
# output_notebook()
#
# p = figure(title="简单折线图", x_axis_label='x', y_axis_label='y')
# p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="温度", line_width=2)
# show(p)
#
# # 34. 使用内嵌交互式地图做笔记
# # 你可以在代码单元格中使用 Folium 创建交互式地图
#
# import folium
#
# m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
# folium.Marker([37.7749, -122.4194], popup="San Francisco").add_to(m)
# m
#
# # 35. 使用内嵌交互式表格做笔记
# # 你可以在代码单元格中使用 QGrid 创建交互式表格
#
# import qgrid
# import pandas as pd
#
# df = pd.DataFrame({
#     'A': [1, 2, 3],
#     'B': [4, 5, 6],
#     'C': [7, 8, 9]
# })
#
# qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
# qgrid_widget
#
# # 36. 使用内嵌交互式 3D 图形做笔记
# # 你可以在代码单元格中使用 Plotly 创建交互式 3D 图形
#
# import plotly.graph_objects as go
#
# fig = go.Figure(data=[go.Mesh3d(x=[0, 1, 2, 0], y=[0, 0, 1, 2], z=[0, 2, 0, 1])])
# fig.show()
#
# # 37. 使用内嵌交互式动画做笔记
# # 你可以在代码单元格中使用 Matplotlib 创建交互式动画
#
# import matplotlib.animation as animation
# import numpy as np
#
# fig, ax = plt.subplots()
#
# x = np.arange(0, 2*np.pi, 0.01)
# line, = ax.plot(x, np.sin(x))
#
# def animate(i):
#     line.set_ydata(np.sin(x + i / 50))  # 更新数据
#     return line,
#
# ani = animation.FuncAnimation(fig, animate, interval=20, blit=True, save_count=50)
# plt.show()
#
# # 38. 使用内嵌交互式控件做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式控件
#
# from IPython.display import display
# import ipywidgets as widgets
#
# slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description='Slider:')
# display(slider)
#
# # 39. 使用内嵌交互式表单做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式表单
#
# from IPython.display import display
# import ipywidgets as widgets
#
# text = widgets.Text(value='', placeholder='输入一些文本', description='文本:')
# button = widgets.Button(description='提交')
# output = widgets.Output()
#
# def on_button_click(b):
#     with output:
#         print(f"你输入了: {text.value}")
#
# button.on_click(on_button_click)
#
# display(text, button, output)
#
# # 40. 使用内嵌交互式图表做笔记
# # 你可以在代码单元格中使用 Bokeh 创建交互式图表
#
# from bokeh.plotting import figure, show
# from bokeh.io import output_notebook
#
# output_notebook()
#
# p = figure(title="简单折线图", x_axis_label='x', y_axis_label='y')
# p.line([1, 2, 3, 4, 5], [6, 7, 2, 4, 5], legend_label="温度", line_width=2)
# show(p)
#
# # 41. 使用内嵌交互式地图做笔记
# # 你可以在代码单元格中使用 Folium 创建交互式地图
#
# import folium
#
# m = folium.Map(location=[37.7749, -122.4194], zoom_start=12)
# folium.Marker([37.7749, -122.4194], popup="San Francisco").add_to(m)
# m
#
# # 42. 使用内嵌交互式表格做笔记
# # 你可以在代码单元格中使用 QGrid 创建交互式表格
#
# import qgrid
# import pandas as pd
#
# df = pd.DataFrame({
#     'A': [1, 2, 3],
#     'B': [4, 5, 6],
#     'C': [7, 8, 9]
# })
#
# qgrid_widget = qgrid.show_grid(df, show_toolbar=True)
# qgrid_widget
#
# # 43. 使用内嵌交互式 3D 图形做笔记
# # 你可以在代码单元格中使用 Plotly 创建交互式 3D 图形
#
# import plotly.graph_objects as go
#
# fig = go.Figure(data=[go.Mesh3d(x=[0, 1, 2, 0], y=[0, 0, 1, 2], z=[0, 2, 0, 1])])
# fig.show()
#
# # 44. 使用内嵌交互式动画做笔记
# # 你可以在代码单元格中使用 Matplotlib 创建交互式动画
#
# import matplotlib.animation as animation
# import numpy as np
#
# fig, ax = plt.subplots()
#
# x = np.arange(0, 2*np.pi, 0.01)
# line, = ax.plot(x, np.sin(x))
#
# def animate(i):
#     line.set_ydata(np.sin(x + i / 50))  # 更新数据
#     return line,
#
# ani = animation.FuncAnimation(fig, animate, interval=20, blit=True, save_count=50)
# plt.show()
#
# # 45. 使用内嵌交互式控件做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式控件
#
# from IPython.display import display
# import ipywidgets as widgets
#
# slider = widgets.IntSlider(value=5, min=0, max=10, step=1, description='Slider:')
# display(slider)
#
# # 46. 使用内嵌交互式表单做笔记
# # 你可以在代码单元格中使用 IPython 创建交互式表单
#
# from IPython.display import display
# import ipywidgets as widgets
#
# text = widgets.Text(value='', placeholder='输入一些文本', description='文本:')
# button = widgets.Button(description='提交')
# output = widgets.Output()
#
# def on_button_click(b):
#     with output:
#         print(f"你输入了: {text.value}")
#
# button.on_click(on_button
